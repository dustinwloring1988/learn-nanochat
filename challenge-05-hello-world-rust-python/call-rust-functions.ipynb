# %% [markdown]
# To build the Rust part:
#
# ```
# uv tool install maturin
# maturin develop
# ```

# %%
import hello_world_rust_python

# %%
hello_world_rust_python.hello_world()
# Out:
# 'Hello World from rust'

# %%
hello_world_rust_python.add(4,5)
# Out:
# 9

# %%
hello_world_rust_python.sum_list([1,2,3])
# Out:
# 6
